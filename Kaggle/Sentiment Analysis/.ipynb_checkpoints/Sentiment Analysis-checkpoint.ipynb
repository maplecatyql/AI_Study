# %%
import torch
from torch import nn
import pandas as pd
import numpy as np
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.feature_extraction.text import CountVectorizer

# %%
class IMDBDataset:
    def __init__(self, csv_path, mode='train', valid_ratio=0.15, test_ratio=0.1):
        self.mode = mode
        self.data_info = pd.read_csv(csv_path)
        self.data_len = (int)(len(self.data_info))
        self.train_valid_len = (int)(self.data_len * (1 - test_ratio))
        self.train_len = (int)(self.train_valid_len * (1 - valid_ratio))

        if self.mode == 'train':
            self.train_text = np.asarray(self.data_info.iloc[0:self.train_len, 0])
            self.train_label = np.asarray(self.data_info.iloc[0:self.train_len, 1])
            self.text_arr = self.train_text
            self.label_arr = self.train_label
        elif self.mode == 'valid':
            self.valid_text = np.asarray(self.data_info.iloc[self.train_len:, 0])
            self.valid_label = np.asarray(self.data_info.iloc[self.train_len:, 1])
            self.text_arr = self.valid_text
            self.label_arr = self.valid_label
        elif self.mode == 'test':
            self.test_text = np.asarray(self.data_info.iloc[self.train_valid_len:, 0])
            self.text_arr = self.test_text
            # 测试集的标签最后才用到
            self.test_label = np.asarray(self.data_info.iloc[self.train_valid_len:, 1])
        else:
            raise ValueError
            
        self.real_len = len(self.text_arr)
        
        print('Finished reading the {} set of Leaves Dataset ({} samples found)'.format(mode, self.real_len))
        
    def __getitem__(self, index):
        if self.mode != 'test':
            return self.text_arr[index], class2num[self.label_arr[index]]
        else:
            return self.text_arr[index], 'None'
        
    
    def __len__(self):
        return self.real_len

# %%
csv_path = './IMDB Dataset.csv'
train_dataset = IMDBDataset(csv_path, 'train')
valid_dataset = IMDBDataset(csv_path, 'valid')
test_dataset = IMDBDataset(csv_path, 'test')
test_dataset[1]
# Out:
# Finished reading the train set of Leaves Dataset (38250 samples found)
# Finished reading the valid set of Leaves Dataset (11750 samples found)
# Finished reading the test set of Leaves Dataset (5000 samples found)
# ('MacArthur is a great movie with a great story about a great man\x85General Douglas MacArthur. This is of course, the story of one of America\'s great military figures, and a figure made familiar to me from the earliest moments of my memory. Though there is a continuity issue (there may be others) e.g. MacArthur\'s speech portrayed in the film as his 1962 address to the U.S. Military Academy on accepting the Thayer award did not contain the phrase "old soldiers never die; they just fade away." (That was in his speech to Congress upon his dismissal by President Truman) in 1951 for his alleged insubordination (these two did not see eye to eye!) Gregory Peck is im-Peck-able as the general who vowed he would return to the Philippines in World War II. The film moves quickly and easily with the General, his family and his staff from the beginning of the Second World War to the end of his service career. This film would be of much greater significance to one familiar with both WW II and the Korean War. Nevertheless, Peck\'s portrayal of this great man who fought the twin evils of fascism and communism and who hated war as only a soldier can is a memorable one indeed. "In war there is no substitute for victory."',
#  'None')

# %%
def get_device():
    return 'cuda' if torch.cuda.is_available() else 'cpu'

device = get_device()
device
# Out:
# 'cpu'

# %%
class Sequence(Dataset):
    """ 文本预处理 """
    def __init__(self, data, max_seq_len):
        # 句子的最长长度 少于: 用<pad>填补 多余: 截断
        self.max_seq_len = max_seq_len
        df = data
        
        # BOW 以后换Bert
        vectorizer = CountVectorizer(stop_words="english", min_df=0.015)
        vectorizer.fit(df.review.tolist())
        
        # 创建词汇表
        self.token2idx = vectorizer.vocabulary_
        self.token2idx['<pad>'] = max(self.token2idx.values()) + 1
        
        # 词元化工具
        tokenizer = vectorizer.build_analyzer()
        
        # 词元转换为整数索引
        self.encode = lambda x : [self.token2idx[token] for token in tokenizer(x) if token in self.token2idx]
        # 将少于max_seq_len的地方用特殊符号 <pad> 补齐
        self.pad = lambda x : x + (max_seq_len - len(x)) * [self.token2idx['<pad>']]
        
        sequences = [self.encode(sequence)[:max_seq_len] for sequence in df.review.tolist()]
        sequences, self.labels = zip(*[(sequence, label) for sequence, label in zip(sequences, df.label.tolist()) if sequence])
        
        # 填补
        self.sequences = [self.pad(sequence) for sequence in sequences]
        
    def __getitem__(self, index):
        assert len(self.sequences[index]) == max_seq_len
        return self.sequences[i], self.labels[index]
    
    def __len__(self):
        return len(self.sequences)

# %%
data = pd.read_csv("./IMDB Dataset.csv")
data['label'] = data['sentiment']
del data['sentiment']
data
# Out:
#                                                   review     label
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
labeling = {
    'positive': 1,
    'negative': 0
}

# %%
# 将标签转化为整数 积极对应1 消极对应0
data['label'] = data['label'].apply(lambda x : labeling[x])
data
# Out:
#                                                   review  label
# 0      One of the other reviewers has mentioned that ...      1
# 1      A wonderful little production. <br /><br />The...      1
# 2      I thought this was a wonderful way to spend ti...      1
# 3      Basically there's a family where a little boy ...      0
# 4      Petter Mattei's "Love in the Time of Money" is...      1
# ...                                                  ...    ...
# 49995  I thought this movie did a down right good job...      1
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...      0
# 49997  I am a Catholic taught in parochial elementary...      0
# 49998  I'm going to have to disagree with the previou...      0
# 49999  No one expects the Star Trek movies to be high...      0
#
# [50000 rows x 2 columns]

# %%
data.shape
# Out:
# (50000, 2)

# %%
# 实例化
dataset = Sequence(data, max_seq_len=128)

# %%
dataset.token2idx
# Out:
# {'mentioned': 575,
#  'watching': 999,
#  'just': 476,
#  'episode': 279,
#  'll': 531,
#  'right': 755,
#  'exactly': 290,
#  'happened': 404,
#  'br': 97,
#  'thing': 917,
#  'scenes': 778,
#  'violence': 983,
#  'set': 799,
#  'word': 1019,
#  'sex': 802,
#  'classic': 146,
#  'use': 965,
#  'called': 111,
#  'given': 380,
#  'state': 863,
#  'city': 144,
#  'face': 303,
#  'high': 421,
#  'home': 428,
#  'death': 208,
#  'far': 319,
#  'away': 59,
#  'say': 772,
#  'main': 548,
#  'appeal': 40,
#  'fact': 304,
#  'goes': 385,
#  'shows': 814,
#  'wouldn': 1029,
#  'forget': 356,
#  'pretty': 700,
#  'pictures': 665,
#  'audiences': 55,
#  'romance': 761,
#  'doesn': 240,
#  'mess': 576,
#  'saw': 771,
#  'couldn': 180,
#  'watched': 998,
#  'taste': 903,
#  'got': 390,
#  'kill': 481,
#  'order': 635,
#  'middle': 579,
#  'class': 145,
#  'turned': 951,
#  'lack': 494,
#  'street': 873,
#  'experience': 298,
#  'viewing': 981,
#  'touch': 936,
#  'wonderful': 1018,
#  'little': 527,
#  'production': 708,
#  'old': 629,
#  'time': 926,
#  'gives': 381,
#  'sense': 793,
#  'entire': 277,
#  'piece': 666,
#  'actors': 17,
#  'extremely': 300,
#  'michael': 578,
#  'truly': 946,
#  'editing': 260,
#  'worth': 1028,
#  'written': 1035,
#  'great': 392,
#  'master': 560,
#  'comedy': 155,
#  'life': 517,
#  'really': 729,
#  'comes': 156,
#  'things': 918,
#  'fantasy': 318,
#  'dream': 249,
#  'remains': 740,
#  'solid': 834,
#  'plays': 675,
#  'particularly': 644,
#  'sets': 800,
#  'flat': 347,
#  'thought': 922,
#  'way': 1001,
#  'spend': 849,
#  'hot': 435,
#  'sitting': 824,
#  'air': 29,
#  'theater': 915,
#  'light': 518,
#  'plot': 677,
#  'dialogue': 221,
#  'characters': 132,
#  'killer': 483,
#  'disappointed': 233,
#  'realize': 728,
#  'point': 679,
#  'control': 174,
#  'style': 878,
#  'love': 543,
#  'years': 1040,
#  've': 975,
#  'managed': 556,
#  'tone': 932,
#  'sexy': 804,
#  'average': 57,
#  'young': 1043,
#  'woman': 1014,
#  'career': 116,
#  'interesting': 463,
#  'friends': 362,
#  'basically': 69,
#  'family': 313,
#  'boy': 95,
#  'thinks': 921,
#  'parents': 642,
#  'fighting': 334,
#  'movie': 596,
#  'suddenly': 883,
#  'decides': 212,
#  'ok': 627,
#  'going': 386,
#  'make': 550,
#  'film': 337,
#  'decide': 210,
#  'thriller': 923,
#  'drama': 247,
#  'like': 519,
#  'real': 725,
#  'totally': 935,
#  'expected': 296,
#  'similar': 817,
#  'instead': 459,
#  '10': 0,
#  'playing': 674,
#  'shots': 810,
#  'money': 590,
#  'watch': 997,
#  'mr': 599,
#  'human': 440,
#  'telling': 907,
#  'power': 694,
#  'success': 881,
#  'people': 652,
#  'different': 226,
#  'situations': 826,
#  'play': 672,
#  'theme': 916,
#  'director': 231,
#  'action': 15,
#  'present': 699,
#  'new': 613,
#  'york': 1042,
#  'meet': 569,
#  'person': 658,
#  'know': 489,
#  'previous': 701,
#  'look': 535,
#  'taken': 895,
#  'live': 528,
#  'world': 1025,
#  'gets': 375,
#  'picture': 664,
#  'big': 81,
#  'best': 79,
#  'place': 668,
#  'case': 117,
#  'acting': 14,
#  'good': 388,
#  'direction': 230,
#  'rest': 745,
#  'talented': 900,
#  'cast': 118,
#  'come': 154,
#  'alive': 30,
#  'wish': 1013,
#  'work': 1021,
#  'probably': 702,
#  'favorite': 322,
#  'story': 869,
#  'cause': 122,
#  'boring': 91,
#  'despite': 217,
#  'having': 411,
#  'seen': 790,
#  '15': 2,
#  'times': 927,
#  'paul': 650,
#  'performance': 655,
#  'brings': 102,
#  'eyes': 302,
#  'roles': 760,
#  'kids': 480,
#  'says': 774,
#  'children': 139,
#  'makes': 552,
#  'fun': 363,
#  'mother': 593,
#  'slow': 828,
#  'believable': 77,
#  'sure': 889,
#  'series': 797,
#  'today': 929,
#  'bring': 101,
#  'kid': 479,
#  'black': 85,
#  'white': 1009,
#  'tv': 953,
#  'hero': 419,
#  'week': 1004,
#  'need': 610,
#  'change': 127,
#  'pace': 640,
#  'water': 1000,
#  'adventure': 25,
#  'oh': 626,
#  'thank': 913,
#  'view': 978,
#  'movies': 597,
#  'believe': 78,
#  'nice': 614,
#  'read': 723,
#  'plus': 678,
#  'points': 681,
#  'lines': 524,
#  'let': 515,
#  'leave': 510,
#  'doubt': 245,
#  'amazing': 31,
#  'idea': 444,
#  'brilliant': 100,
#  'funny': 364,
#  'complete': 164,
#  'waste': 995,
#  'writing': 1034,
#  'bad': 64,
#  'performances': 656,
#  'entertaining': 275,
#  'hard': 407,
#  'hand': 401,
#  'original': 636,
#  'fit': 346,
#  'felt': 329,
#  'stars': 859,
#  'respect': 744,
#  'huge': 439,
#  'awful': 61,
#  'positive': 689,
#  'comments': 160,
#  'looking': 537,
#  'forward': 358,
#  'films': 340,
#  'worst': 1027,
#  'storyline': 870,
#  'soundtrack': 844,
#  'song': 837,
#  'lame': 496,
#  'country': 181,
#  'played': 673,
#  'looks': 538,
#  'cheap': 134,
#  'happy': 406,
#  'end': 267,
#  'credits': 190,
#  'giving': 382,
#  'score': 782,
#  'making': 553,
#  'bit': 83,
#  'effort': 264,
#  'hell': 417,
#  'liked': 520,
#  'humour': 442,
#  'based': 67,
#  'actual': 19,
#  'odd': 624,
#  'didn': 223,
#  'jokes': 475,
#  'low': 546,
#  'budget': 107,
#  'problem': 703,
#  'eventually': 286,
#  'lost': 539,
#  'imagine': 447,
#  'better': 80,
#  'try': 948,
#  'brother': 104,
#  'came': 112,
#  'scene': 776,
#  'men': 573,
#  'horror': 434,
#  'cheesy': 136,
#  'monster': 591,
#  'type': 956,
#  'usually': 970,
#  'beautiful': 71,
#  'daughter': 202,
#  'died': 225,
#  'care': 115,
#  'romantic': 762,
#  'year': 1039,
#  'predictable': 696,
#  'humor': 441,
#  'later': 500,
#  'loved': 544,
#  'star': 857,
#  'early': 255,
#  'took': 933,
#  'scary': 775,
#  'possible': 690,
#  'fan': 315,
#  'enjoyed': 274,
#  'maybe': 564,
#  'apparently': 39,
#  'bought': 93,
#  'long': 533,
#  'ago': 27,
#  'game': 366,
#  'killing': 484,
#  'secret': 788,
#  'island': 466,
#  'feeling': 327,
#  'names': 605,
#  'actually': 20,
#  'tale': 898,
#  'jack': 470,
#  'yes': 1041,
#  'true': 945,
#  'don': 243,
#  'looked': 536,
#  'evil': 288,
#  'mad': 547,
#  'dr': 246,
#  'reason': 730,
#  'rich': 751,
#  'haven': 410,
#  'gone': 387,
#  'started': 861,
#  'stay': 864,
#  'meaning': 566,
#  'did': 222,
#  'laugh': 501,
#  'annoying': 36,
#  'shoot': 806,
#  'minutes': 583,
#  'screen': 783,
#  'appreciate': 44,
#  'trying': 949,
#  'certain': 124,
#  'tried': 941,
#  'era': 282,
#  'words': 1020,
#  'write': 1031,
#  'english': 271,
#  'saying': 773,
#  'does': 239,
#  'cut': 196,
#  'fantastic': 317,
#  'famous': 314,
#  'george': 374,
#  'man': 555,
#  'everybody': 287,
#  'kind': 486,
#  'unbelievable': 959,
#  'sort': 841,
#  'school': 779,
#  'project': 709,
#  'thinking': 920,
#  'bizarre': 84,
#  'supposed': 888,
#  'town': 939,
#  'involved': 464,
#  'quite': 718,
#  'ridiculous': 754,
#  'lots': 541,
#  'relationship': 737,
#  'dance': 198,
#  'pass': 647,
#  'wasted': 996,
#  'spent': 850,
#  'simply': 819,
#  'fails': 306,
#  'title': 928,
#  'excellent': 292,
#  'feel': 326,
#  'character': 131,
#  'major': 549,
#  'version': 976,
#  'attempts': 52,
#  'earlier': 254,
#  'special': 848,
#  'effects': 263,
#  'enjoy': 272,
#  'older': 630,
#  'horrible': 433,
#  'wasn': 994,
#  'minute': 582,
#  'fight': 333,
#  'chance': 126,
#  'development': 219,
#  'running': 765,
#  'emotional': 266,
#  'wanted': 991,
#  'final': 341,
#  'beginning': 75,
#  'return': 747,
#  'wait': 987,
#  'tell': 906,
#  'line': 523,
#  'conclusion': 168,
#  'adult': 24,
#  'disappointment': 235,
#  'save': 770,
#  'remember': 742,
#  'cinema': 141,
#  'dark': 200,
#  'places': 669,
#  'sister': 822,
#  'appearance': 42,
#  'actor': 16,
#  'think': 919,
#  'shot': 809,
#  'knows': 492,
#  'dvd': 253,
#  'shame': 805,
#  '20': 3,
#  'hear': 413,
#  'female': 330,
#  'perfectly': 654,
#  'fine': 344,
#  'dull': 251,
#  'script': 785,
#  'suppose': 887,
#  'weren': 1007,
#  'couple': 182,
#  'hours': 437,
#  'die': 224,
#  'surprise': 890,
#  'wrong': 1036,
#  'guy': 397,
#  'concept': 167,
#  'stop': 866,
#  'especially': 284,
#  'acted': 13,
#  'plenty': 676,
#  'laughs': 504,
#  'john': 473,
#  'box': 94,
#  'constantly': 172,
#  'painful': 641,
#  'girl': 377,
#  'mention': 574,
#  'using': 968,
#  'help': 418,
#  'needed': 611,
#  'happen': 403,
#  'turn': 950,
#  'terrible': 911,
#  'sequences': 796,
#  'fake': 309,
#  'amusing': 34,
#  'women': 1015,
#  'utterly': 971,
#  'appear': 41,
#  'weird': 1005,
#  'costumes': 179,
#  'absolutely': 10,
#  'won': 1016,
#  'isn': 467,
#  'music': 601,
#  'takes': 896,
#  'heard': 414,
#  'start': 860,
#  'straight': 871,
#  'matter': 563,
#  'used': 966,
#  'hilarious': 423,
#  'lot': 540,
#  'moving': 598,
#  'usual': 969,
#  'animation': 35,
#  'worse': 1026,
#  'bunch': 108,
#  'run': 764,
#  'kept': 478,
#  'pick': 663,
#  'season': 786,
#  'honestly': 430,
#  'barely': 66,
#  'night': 615,
#  'stupid': 877,
#  'means': 567,
#  'unless': 963,
#  'known': 491,
#  'actress': 18,
#  'depth': 215,
#  'cop': 177,
#  'feels': 328,
#  'video': 977,
#  'complex': 166,
#  'details': 218,
#  'dumb': 252,
#  'role': 759,
#  'terrific': 912,
#  'job': 472,
#  'songs': 838,
#  'unfortunately': 961,
#  'masterpiece': 561,
#  'trip': 943,
#  'mind': 580,
#  'aside': 47,
#  'fall': 310,
#  'date': 201,
#  'poorly': 685,
#  'miss': 584,
#  'future': 365,
#  'follow': 350,
#  'door': 244,
#  'want': 990,
#  'personally': 660,
#  'talk': 901,
#  'inside': 458,
#  'agree': 28,
#  'genre': 373,
#  'worked': 1022,
#  'failed': 305,
#  'twist': 954,
#  'subject': 879,
#  'explain': 299,
#  'brain': 98,
#  'wants': 992,
#  'guess': 395,
#  'showed': 811,
#  'reality': 727,
#  'surprised': 891,
#  'cinematography': 143,
#  'walk': 989,
#  'open': 632,
#  'eye': 301,
#  'crazy': 186,
#  'leaving': 512,
#  'audience': 54,
#  'political': 683,
#  'hollywood': 427,
#  'values': 973,
#  'list': 525,
#  'spirit': 851,
#  'war': 993,
#  'poor': 684,
#  'particular': 643,
#  'able': 9,
#  'stand': 854,
#  'america': 32,
#  'typical': 957,
#  'speak': 846,
#  'dancing': 199,
#  'large': 498,
#  'cold': 152,
#  'starring': 858,
#  'law': 505,
#  'entirely': 278,
#  'literally': 526,
#  'battle': 70,
#  'sequence': 795,
#  'puts': 713,
#  'period': 657,
#  'equally': 281,
#  'left': 514,
#  'appears': 43,
#  'somewhat': 835,
#  'soon': 839,
#  'turns': 952,
#  'begins': 76,
#  'ways': 1002,
#  'coming': 158,
#  'course': 183,
#  'tough': 938,
#  'brought': 106,
#  'disturbing': 236,
#  'surprisingly': 892,
#  'father': 321,
#  'changed': 128,
#  'anti': 37,
#  'message': 577,
#  'effective': 262,
#  'past': 648,
#  'century': 123,
#  'effect': 261,
#  'manages': 557,
#  'mood': 592,
#  'atmosphere': 50,
#  'climax': 150,
#  'nature': 607,
#  'unique': 962,
#  'lives': 529,
#  'apart': 38,
#  'suspense': 893,
#  'company': 162,
#  'robert': 757,
#  'happens': 405,
#  'police': 682,
#  'falls': 311,
#  'second': 787,
#  'male': 554,
#  'smart': 831,
#  'sad': 767,
#  'small': 830,
#  'memorable': 572,
#  'hands': 402,
#  'attempt': 51,
#  'novel': 619,
#  'richard': 752,
#  'gay': 369,
#  'murder': 600,
#  'potential': 693,
#  'works': 1024,
#  'general': 370,
#  'girlfriend': 378,
#  'question': 715,
#  'directed': 228,
#  'successful': 882,
#  'leading': 507,
#  'directors': 232,
#  'tells': 908,
#  'unlike': 964,
#  'various': 974,
#  'crime': 193,
#  'leads': 508,
#  'finally': 342,
#  'house': 438,
#  'short': 808,
#  'hair': 399,
#  'moments': 589,
#  'cult': 194,
#  'baby': 62,
#  'quality': 714,
#  'opening': 633,
#  'revenge': 748,
#  'motion': 594,
#  'ultimately': 958,
#  'non': 616,
#  'living': 530,
#  'italian': 469,
#  'speaking': 847,
#  'business': 109,
#  'missing': 586,
#  'close': 151,
#  'fear': 323,
#  'caught': 121,
#  'truth': 947,
#  'told': 930,
#  '50': 5,
#  'half': 400,
#  'days': 205,
#  'release': 738,
#  'uses': 967,
#  'deep': 213,
#  'impossible': 451,
#  'friend': 361,
#  'single': 821,
#  'taking': 897,
#  'waiting': 988,
#  'la': 493,
#  'expecting': 297,
#  'expect': 295,
#  'tension': 909,
#  'fast': 320,
#  'gave': 368,
#  'seriously': 798,
#  'lead': 506,
#  'talent': 899,
#  'certainly': 125,
#  'avoid': 58,
#  'bored': 90,
#  'cute': 197,
#  'sweet': 894,
#  'age': 26,
#  'edge': 259,
#  '100': 1,
#  'wonder': 1017,
#  'hardly': 408,
#  'language': 497,
#  'nudity': 620,
#  'hoping': 432,
#  'television': 905,
#  'rated': 721,
#  'rent': 743,
#  'needs': 612,
#  'portrayed': 688,
#  'ones': 631,
#  'aspect': 49,
#  'number': 621,
#  'including': 454,
#  'begin': 74,
#  'created': 188,
#  'purpose': 712,
#  'add': 21,
#  'act': 12,
#  'completely': 165,
#  'hope': 431,
#  'following': 351,
#  '80': 6,
#  'value': 972,
#  'obviously': 623,
#  'figure': 335,
#  'okay': 628,
#  'david': 203,
#  'ride': 753,
#  'greatest': 393,
#  'writer': 1032,
#  'husband': 443,
#  'thrown': 925,
#  'shooting': 807,
#  'clearly': 148,
#  'camera': 113,
#  'child': 138,
#  'creepy': 191,
#  'went': 1006,
#  'casting': 119,
#  'hold': 426,
#  'james': 471,
#  'entertainment': 276,
#  'recommend': 734,
#  'book': 89,
#  'issues': 468,
#  'personal': 659,
#  'background': 63,
#  'oscar': 637,
#  'doctor': 237,
#  'william': 1011,
#  'chemistry': 137,
#  'ending': 269,
#  'consider': 169,
#  'stories': 868,
#  'example': 291,
#  'changes': 129,
#  'dialog': 220,
#  'local': 532,
#  'gun': 396,
#  'killed': 482,
#  'hit': 425,
#  'god': 384,
#  'starts': 862,
#  'highly': 422,
#  'events': 285,
#  'level': 516,
#  'laughable': 502,
#  'contains': 173,
#  'available': 56,
#  'working': 1023,
#  'american': 33,
#  'car': 114,
#  'grade': 391,
#  'hour': 436,
#  'heavy': 416,
#  'musical': 602,
#  'parts': 645,
#  'compared': 163,
#  'singing': 820,
#  'common': 161,
#  'opinion': 634,
#  'obvious': 622,
#  'talking': 902,
#  'enjoyable': 273,
#  'supporting': 886,
#  'earth': 256,
#  'stuff': 876,
#  'public': 710,
#  'nearly': 609,
#  'late': 499,
#  'screenplay': 784,
#  'imdb': 448,
#  'situation': 825,
#  'tom': 931,
#  'head': 412,
#  'wife': 1010,
#  'voice': 986,
#  'sees': 791,
#  'pure': 711,
#  'thanks': 914,
#  'younger': 1044,
#  'son': 836,
#  'total': 934,
#  'note': 618,
#  'rate': 720,
#  'social': 832,
#  'normal': 617,
#  'western': 1008,
#  'simple': 818,
#  'premise': 697,
#  'minor': 581,
#  'getting': 376,
#  'learn': 509,
#  'sound': 842,
#  'moves': 595,
#  'spoilers': 852,
#  'familiar': 312,
#  'innocent': 457,
#  'forced': 355,
#  'ended': 268,
#  'married': 559,
#  'french': 360,
#  'violent': 984,
#  'knew': 488,
#  'ability': 8,
#  'day': 204,
#  'members': 571,
#  'seeing': 789,
#  'heart': 415,
#  'added': 22,
#  'decided': 211,
#  'kills': 485,
#  'dead': 206,
#  'fans': 316,
#  'rating': 722,
#  'space': 845,
#  'post': 692,
#  'shown': 813,
#  'stands': 856,
#  'self': 792,
#  'create': 187,
#  'ends': 270,
#  'difficult': 227,
#  'documentary': 238,
#  'mark': 558,
#  'viewer': 979,
#  'fair': 307,
#  'problems': 704,
#  '90': 7,
#  'group': 394,
#  'blood': 86,
#  'gore': 389,
#  'decent': 209,
#  'leaves': 511,
#  'office': 625,
#  'outside': 638,
#  'british': 103,
#  'knowing': 490,
#  'producer': 706,
#  'directing': 229,
#  'elements': 265,
#  'perfect': 653,
#  'meets': 570,
#  'popular': 686,
#  'form': 357,
#  'incredibly': 456,
#  'art': 46,
#  'clever': 149,
#  'twists': 955,
#  'drug': 250,
#  'store': 867,
#  'king': 487,
#  'sick': 815,
#  'stage': 853,
#  'convincing': 175,
#  'aren': 45,
#  'peter': 661,
#  'important': 450,
#  'longer': 534,
#  'terms': 910,
#  'disappointing': 234,
#  'lovely': 545,
#  'impressive': 453,
#  'named': 604,
#  'easily': 257,
#  'remake': 741,
#  'silly': 816,
#  'force': 354,
#  'ex': 289,
#  'mystery': 603,
#  'strong': 874,
#  'recommended': 735,
#  'check': 135,
#  'strange': 872,
#  'boys': 96,
#  'material': 562,
#  'bother': 92,
#  'definitely': 214,
#  'beauty': 73,
#  'free': 359,
#  'easy': 258,
#  'trouble': 944,
#  'crap': 185,
#  'presence': 698,
#  'slightly': 827,
#  'visual': 985,
#  'producers': 707,
#  'sequel': 794,
#  'sorry': 840,
#  'brothers': 105,
#  'produced': 705,
#  'throw': 924,
#  'room': 763,
#  'overall': 639,
#  'awesome': 60,
#  'clear': 147,
#  'honest': 429,
#  'beautifully': 72,
#  'filmed': 338,
#  'considered': 170,
#  'feature': 324,
#  'released': 739,
#  'showing': 812,
#  'subtle': 880,
#  'pathetic': 649,
#  '30': 4,
#  'doing': 242,
#  'focus': 349,
#  'super': 884,
#  'college': 153,
#  'tries': 942,
#  'lee': 513,
#  'biggest': 82,
#  'modern': 587,
#  'hate': 409,
#  'finds': 343,
#  'intended': 461,
#  'keeps': 477,
#  'flick': 348,
#  'dog': 241,
#  'girls': 379,
#  'team': 904,
#  'guys': 398,
#  'yeah': 1038,
#  'cool': 176,
#  'reviews': 750,
#  'immediately': 449,
#  'follows': 352,
#  'rare': 719,
#  'impression': 452,
#  'incredible': 455,
#  'genius': 372,
#  'moment': 588,
#  'ask': 48,
#  'sit': 823,
#  'filled': 336,
#  'fiction': 332,
#  'weak': 1003,
#  'ideas': 445,
#  'quickly': 717,
#  'joke': 474,
#  'finish': 345,
#  'touching': 937,
#  'mean': 565,
#  'interested': 462,
#  'reading': 724,
#  'accent': 11,
#  'rock': 758,
#  'said': 769,
#  'sadly': 768,
#  'pointless': 680,
#  'hey': 420,
#  'villain': 982,
#  'glad': 383,
#  'comment': 159,
#  'natural': 606,
#  'possibly': 691,
#  'red': 736,
#  'fairly': 308,
#  'involving': 465,
#  'understand': 960,
#  'plain': 670,
#  'superb': 885,
#  'writers': 1033,
#  'near': 608,
#  'questions': 716,
#  'excuse': 294,
#  'comic': 157,
#  'garbage': 367,
#  'buy': 110,
#  'stick': 865,
#  'trash': 940,
#  'meant': 568,
#  'studio': 875,
#  'pieces': 667,
#  'runs': 766,
#  'crew': 192,
#  'cinematic': 142,
#  'history': 424,
#  'copy': 178,
#  'wrote': 1037,
#  'review': 749,
#  'realistic': 726,
#  'loud': 542,
#  'scenery': 777,
#  'choice': 140,
#  'cover': 184,
#  'footage': 353,
#  'body': 88,
#  'blue': 87,
#  'badly': 65,
#  'win': 1012,
#  'sci': 780,
#  'fi': 331,
#  'sexual': 803,
#  'escape': 283,
#  ...}

# %%
def collate(batch):
    inputs = torch.LongTensor([item[0] for item in batch])
    target = torch.FloatTensor([item[1] for item in batch])
    return inputs, target

batch_size = 2048
train_loader = DataLoader(batch_size, collate_fn=collate)

# %%
class RNN(nn.Module):
    def __init__(self, vocab_size, batch_size, embedding_size=100, hidden_size=128, n_layers=1, device='cpu'):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
